# %% [markdown]
# <a href="https://colab.research.google.com/github/ebayuk/singtomeabelrepo/blob/main/singtomeabel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##trying to figure out how to extract only the text from the weeknd json downloaded from hugging face so can then follow the video tutorial to create genai model

# %%
with open('dataset.json', 'r', encoding = 'utf-8') as f:
  text = f.read()

# %%
# !wget https://huggingface.co/datasets/huggingartists/the-weeknd/blob/main/datasets.json
# Out:
# --2023-08-13 20:49:25--  https://huggingface.co/datasets/huggingartists/the-weeknd/blob/main/datasets.json
# Resolving huggingface.co (huggingface.co)... 108.138.94.27, 108.138.94.97, 108.138.94.45, ...
# Connecting to huggingface.co (huggingface.co)|108.138.94.27|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 41679 (41K) [text/html]
# Saving to: ‘datasets.json’
#
# datasets.json       100%[===================>]  40.70K  --.-KB/s    in 0.005s
#
# 2023-08-13 20:49:25 (7.87 MB/s) - ‘datasets.json’ saved [41679/41679]

# %%
with open('datasets.json', 'r', encoding = 'utf-8', newline='\n') as f:
  text = f.read()

# %%
# !wget "https://datasets-server.huggingface.co/rows?dataset=huggingartists%2Fthe-weeknd&config=default&split=train&offset=0&limit=100"
# Out:
# --2023-08-13 20:54:53--  https://datasets-server.huggingface.co/rows?dataset=huggingartists%2Fthe-weeknd&config=default&split=train&offset=0&limit=100
# Resolving datasets-server.huggingface.co (datasets-server.huggingface.co)... 18.211.243.137, 3.227.142.36, 52.201.174.4, ...
# Connecting to datasets-server.huggingface.co (datasets-server.huggingface.co)|18.211.243.137|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 211225 (206K) [application/json]
# Saving to: ‘rows?dataset=huggingartists%2Fthe-weeknd&config=default&split=train&offset=0&limit=100’
#
# rows?dataset=huggin 100%[===================>] 206.27K  --.-KB/s    in 0.1s
#
# 2023-08-13 20:54:54 (1.59 MB/s) - ‘rows?dataset=huggingartists%2Fthe-weeknd&config=default&split=train&offset=0&limit=100’ saved [211225/211225]

# %%
text
# Out:
# '{"features":[{"feature_idx":0,"name":"text","type":{"dtype":"string","_type":"Value"}}],"rows":[{"row_idx":0,"row":{"text":"Yeah\\nYeah\\nYeah\\nYour man on the road, he doin promo\\nYou said, \\"Keep our business on the low-low\\"\\nIm just tryna get you out the friend zone\\nCause you look even better than the photos\\nI cant find your house, send me the info\\nDrivin through the gated residential\\nFound out I was comin, sent your friends home\\nKeep on tryna hide it, but your friends know\\nI only call you when its half-past five\\nThe only time that Ill be by your side\\nI only love it when you touch me, not feel me\\nWhen Im fucked up, thats the real me\\nWhen Im fucked up, thats the real me, yeah\\nI only call you when its half-past five\\nThe only time Id ever call you mine\\nI only love it when you touch me, not feel me\\nWhen Im fucked up, thats the real me\\nWhen Im fucked up, thats the real me, babe\\nIma let you know and keep it simple\\nTryna keep it up dont seem so si
# ...

# %%
y = json.loads(text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0dc740fec4a7> in <cell line: 1>()
# ----> 1 y = json.loads(text)
#
# NameError: name 'json' is not defined

# %%
import json

# %%
y = json.loads(text)

# %%
rows = y['rows']

# %%
for key in y:
  print(key,y[key])
# Out:
# features [{'feature_idx': 0, 'name': 'text', 'type': {'dtype': 'string', '_type': 'Value'}}]
# ...

# %%
for i in rows:
  print(type(i))
# Out:
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# <class 'dict'>
# ...

# %%
import more_itertools as mt

# %%
list(mt.collapse(rows))
# Out:
# ['row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
#  'truncated_cells',
#  'row_idx',
#  'row',
# ...
